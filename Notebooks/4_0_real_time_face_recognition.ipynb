# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import sys
CURRENT_DIR = Path('.').resolve()

# %%
MODULES_DIR = CURRENT_DIR.parent.joinpath('src')
sys.path.append(str(MODULES_DIR))
DATA_DIR = CURRENT_DIR.parent.joinpath('Data')

# %% [markdown]
# -----
#
# # Creating a real-time face recognition program
#
# We are going to put together the code that we have writeen so far to create a real-time face recognition program. This program will use the webcam in our computer for facial recognition, and to authenticate whether the person sitting in front of the webcam is indeed you.
#
# To do so, the program needs to do he following:
#
# 1. Train a Siamese neural network for facial recognition
# 2. Use the webcam to capture a true image of the authorized user. This is the onboarding process of the facial recognition system.
# 3. Subsequently, when a user wants to unlock the program, use the pre-trained Siamse neural network from the step 1 and the true image from step 2 to authenticate the user.
#
# -----
#
# ## The onboarding process
#
# During the onboarding process, we need to activate the webcam to capture a true image of the authorized user. OpenCB has a function called `VideoCapture` that allows us to activate and capture the image from the computer's webcam

# %%
import cv2
video_capture = cv2.VideoCapture(0)

# %% [markdown]
# Let's give the user five seconds to prepare before taking a photo using the webcam. We start a `counter` variable woth an initial value of 5 and snap a photo using thw webcam once the counter reaches 0.

# %%
import math
import face_detector


fc_dir = CURRENT_DIR.joinpath(
    'models','haarcascade_frontalface_default.xml'
    )
face_cascades = face_detector.import_cascades(fc_dir)

# %%
counter = 5

while True:
    _, frame = video_capture.read()
    frame, face_box, face_coords = face_detector.detect_faces(frame, face_cascades)
    text = 'Image will be taken in {}..'.format(math.ceil(counter))
    if face_box is not None:
        frame = face_detector.write_on_frame(frame, text, face_coords[0], face_coords[1]-10)
        cv2.imshow('Video',frame)
        cv2.waitKey(1)
        counter -= 0.1
        if counter <= 0:
            cv2.imwrite('true_img.png', face_box)
            break

video_capture.release()
cv2.destroyAllWindows()
print('Onboarding image capture')
# Out:
# KeyboardInterrupt
